# %% [markdown]
# <a href="https://colab.research.google.com/github/felexkuria/100-days-of-web-development/blob/main/plp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data= pd.read_csv('todays_data.csv')
data.describe()
print(data['Academic Level'].value_counts())




# with open('todays_data.csv', 'r') as file:
#     lines = file.read()
#     print(lines)
# Out:
# Academic Level
# UnderGraduate    204
# HighSchool        52
# undergraduate     34
# Diploma           33
# secondary         15
# diploma            7
# PostGraduate       4
# other              1
# Name: count, dtype: int64

# %%
data2=data.value_counts('Academic Level')
data2.plot()
# Out:
# <Axes: xlabel='Academic Level'>

# %%
data2.plot.bar()
# Out:
# <Axes: xlabel='Academic Level'>

# %%
data=data.value_counts('Academic Level')
print(data)
# Out:
# Academic Level
# UnderGraduate    204
# HighSchool        52
# undergraduate     34
# Diploma           33
# secondary         15
# diploma            7
# PostGraduate       4
# other              1
# Name: count, dtype: int64
